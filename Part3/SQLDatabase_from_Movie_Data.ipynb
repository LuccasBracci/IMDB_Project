# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sqlalchemy as sqlay
import pymysql as msql
import glob
import gzip
import os
import re
import warnings
warnings.filterwarnings('ignore')

msql.install_as_MySQLdb()

# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from scipy import stats
from scipy.stats import ttest_ind, shapiro, levene

# %% [markdown]
# # SQL Engine initialization

# %%
filepath = '/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/Week1/Books/enc.json'
filepath
# Out:
# '/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/Week1/Books/enc.json'

# %%
with open(filepath, 'r') as f:
    envs = json.load(f)

# %%
username = envs['user']
password = envs['password']
db_name = 'movie_db'

connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)

# %%
conc = {
    'user' : envs['user'],
    'password' : envs['password'],
    'database' : 'movie_db'
}

# %%
if database_exists(connection) == False: 
  create_database(connection)
else: 
  print('The database already exists.')
# Out:
# The database already exists.

# %%
con = msql.connect(**conc)

# %% [markdown]
# # Database normalization and preparation

# %%
basics = "/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/IMDB/DataMain/basics.csv.gz"
ratings = "/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/IMDB/DataMain/ratings.csv.gz"
movies_folder = "/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/IMDB/DataSecondary/"

# %% [markdown]
# ### Basics

# %%
basics = pd.read_csv(basics, compression='gzip')

basics
# Out:
#        Unnamed: 0     tconst titleType  \
# 0           34803  tt0035423     movie
# 1           42384  tt0043139     movie
# 2           61115  tt0062336     movie
# 3           67668  tt0069049     movie
# 4           86800  tt0088751     movie
# ...           ...        ...       ...
# 81757     9926017  tt9914942     movie
# 81758     9926412  tt9915872     movie
# 81759     9926552  tt9916170     movie
# 81760     9926561  tt9916190     movie
# 81761     9926645  tt9916362     movie
#
#                                             primaryTitle  \
# 0                                         Kate & Leopold
# 1                            Life of a Beijing Policeman
# 2      The Tango of the Widower and Its Distorting Mi...
# 3                             The Other Side of the Wind
# 4                                      The Naked Monster
# ...                                                  ...
# 81757                             Life Without Sara Amat
# 81758                               The Last White Witch
# 81759                                      The Rehearsal
# 81760                                          Safeguard
# 81761                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1                               Wo zhe yi bei zi        0     2013.0      NaN
# 2      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 3                     The Other Side of the Wind        0     2018.0      NaN
# 4                              The Naked Monster        0     2005.0      NaN
# ...                                          ...      ...        ...      ...
# 81757                 La vida sense la Sara Amat        0     2019.0      NaN
# 81758                  My Girlfriend is a Wizard        0     2019.0      NaN
# 81759                                   O Ensaio        0     2019.0      NaN
# 81760                                  Safeguard        0     2020.0      NaN
# 81761                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                 120              Drama,History
# 2                  70                      Drama
# 3                 122                      Drama
# 4                 100       Comedy,Horror,Sci-Fi
# ...               ...                        ...
# 81757              74                      Drama
# 81758              97       Comedy,Drama,Fantasy
# 81759              51                      Drama
# 81760              95  Action,Adventure,Thriller
# 81761              92              Drama,History
#
# [81762 rows x 10 columns]

# %% [markdown]
# ### Ratings

# %%
ratings = pd.read_csv(ratings, compression='gzip')

ratings
# Out:
#         Unnamed: 0     tconst  averageRating  numVotes
# 0                0  tt0000001            5.7      1979
# 1                1  tt0000002            5.8       265
# 2                4  tt0000005            6.2      2621
# 3                5  tt0000006            5.1       182
# 4                6  tt0000007            5.4       821
# ...            ...        ...            ...       ...
# 501003     1318697  tt9916200            8.1       229
# 501004     1318698  tt9916204            8.2       263
# 501005     1318705  tt9916348            8.3        18
# 501006     1318706  tt9916362            6.4      5374
# 501007     1318711  tt9916428            3.8        14
#
# [501008 rows x 4 columns]

# %% [markdown]
# ### TMDB

# %%
TMDB_Folder = "/Users/Peach/Dropbox/Dojo-env/dojo-env-setup/Stack4/IMDB_Project/Datasets/tmdb_results_combined.csv.gz"

# %%
tmdb_data = pd.read_csv(TMDB_Folder, compression='gzip')

tmdb_data
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1     tt0113092    0.0                               NaN
# 2     tt0116391    0.0                               NaN
# 3     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4     tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
# ...         ...    ...                               ...
# 2572  tt7797790    0.0                               NaN
# 2573  tt8665056    0.0                               NaN
# 2574  tt8795764    0.0                               NaN
# 2575  tt9071078    0.0                               NaN
# 2576  tt9212730    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN  10000000.0
# 1                                                   NaN         0.0
# 2                                                   NaN         0.0
# 3     {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
# 4                                                   NaN         0.0
# ...                                                 ...         ...
# 2572                                                NaN         0.0
# 2573                                                NaN         0.0
# 2574                                                NaN         0.0
# 2575                                                NaN         0.0
# 2576                                                NaN         0.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              [{'id': 878, 'name': 'Science Fiction'}]
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 2572                     [{'id': 27, 'name': 'Horror'}]
# 2573                    [{'id': 37, 'name': 'Western'}]
# 2574                     [{'id': 27, 'name': 'Horror'}]
# 2575                     [{'id': 28, 'name': 'Action'}]
# 2576  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage        id  \
# 0                                                   NaN   62127.0
# 1                                                   NaN  110977.0
# 2                                                   NaN  442869.0
# 3                                                   NaN     843.0
# 4                                                   NaN   49511.0
# ...                                                 ...       ...
# 2572                                                NaN  956219.0
# 2573  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 2574  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 2575                                                NaN  201706.0
# 2576                                                NaN  382630.0
#
#      original_language                       original_title  ...     revenue  \
# 0                   en                      The Fantasticks  ...         0.0
# 1                   en                        For the Cause  ...         0.0
# 2                   hi                                 Gang  ...         0.0
# 3                   cn                                 花樣年華  ...  14204632.0
# 4                   en                       Chinese Coffee  ...         0.0
# ...                ...                                  ...  ...         ...
# 2572                en  Edmund Kemper Part 3: La mort sévit  ...         0.0
# 2573                en                 Guns Along The Bravo  ...         0.0
# 2574                en                            New Breed  ...         0.0
# 2575                cn                                 致命密函  ...         0.0
# 2576                ja                           実録外伝 ゾンビ極道  ...         0.0
#
#       runtime                                   spoken_languages    status  \
# 0        86.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1       100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2       152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3        99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4        99.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 2572     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2573     85.0                                                 []  Released
# 2574     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2575     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 2576     88.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 0         Try to remember the first time magic happened
# 1          The ultimate showdown on a forbidden planet.
# 2                                                   NaN
# 3     Feel the heat, keep the feeling burning, let t...
# 4     There's a fine line between friendship and bet...
# ...                                                 ...
# 2572                                                NaN
# 2573  Evil came to the Southwest until three blazing...
# 2574                                                NaN
# 2575                                                NaN
# 2576                                                NaN
#
#                                     title  video  vote_average vote_count  \
# 0                         The Fantasticks    0.0         5.500       22.0
# 1                           For the Cause    0.0         5.100        8.0
# 2                                    Gang    0.0         4.000        1.0
# 3                    In the Mood for Love    0.0         8.112     2239.0
# 4                          Chinese Coffee    0.0         6.800       50.0
# ...                                   ...    ...           ...        ...
# 2572  Edmund Kemper Part 3: La mort sévit    0.0         0.000        0.0
# 2573                 Guns Along The Bravo    0.0         0.000        0.0
# 2574                            New Breed    0.0         0.000        0.0
# 2575                       Chinese Heroes    0.0         3.000        2.0
# 2576                        Yakuza Zombie    0.0         0.000        0.0
#
#      certification
# 0              NaN
# 1              NaN
# 2              NaN
# 3               PG
# 4                R
# ...            ...
# 2572           NaN
# 2573           NaN
# 2574            NR
# 2575           NaN
# 2576           NaN
#
# [2577 rows x 26 columns]

# %%
# movies = {}

# for file_name in os.listdir(movies_folder):
#     if file_name.endswith('.csv.gz') and 'final_tmdb_data' in file_name:
#         file_path = os.path.join(movies_folder, file_name)
        
#         # Read the compressed CSV file into a DataFrame
#         with gzip.open(file_path, 'rt', encoding='utf-8') as file:
#             df = pd.read_csv(file, index_col=None)
            
#             # Get the base name of the file without extension
#             file_key = os.path.splitext(os.path.basename(file_name))[0]
                        
#             # Store the DataFrame in the dictionary
#             movies[file_key] = df

# print(movies)

# %%
tmdb_data
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1     tt0113092    0.0                               NaN
# 2     tt0116391    0.0                               NaN
# 3     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4     tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
# ...         ...    ...                               ...
# 2572  tt7797790    0.0                               NaN
# 2573  tt8665056    0.0                               NaN
# 2574  tt8795764    0.0                               NaN
# 2575  tt9071078    0.0                               NaN
# 2576  tt9212730    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN  10000000.0
# 1                                                   NaN         0.0
# 2                                                   NaN         0.0
# 3     {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
# 4                                                   NaN         0.0
# ...                                                 ...         ...
# 2572                                                NaN         0.0
# 2573                                                NaN         0.0
# 2574                                                NaN         0.0
# 2575                                                NaN         0.0
# 2576                                                NaN         0.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              [{'id': 878, 'name': 'Science Fiction'}]
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 2572                     [{'id': 27, 'name': 'Horror'}]
# 2573                    [{'id': 37, 'name': 'Western'}]
# 2574                     [{'id': 27, 'name': 'Horror'}]
# 2575                     [{'id': 28, 'name': 'Action'}]
# 2576  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage        id  \
# 0                                                   NaN   62127.0
# 1                                                   NaN  110977.0
# 2                                                   NaN  442869.0
# 3                                                   NaN     843.0
# 4                                                   NaN   49511.0
# ...                                                 ...       ...
# 2572                                                NaN  956219.0
# 2573  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 2574  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 2575                                                NaN  201706.0
# 2576                                                NaN  382630.0
#
#      original_language                       original_title  ...     revenue  \
# 0                   en                      The Fantasticks  ...         0.0
# 1                   en                        For the Cause  ...         0.0
# 2                   hi                                 Gang  ...         0.0
# 3                   cn                                 花樣年華  ...  14204632.0
# 4                   en                       Chinese Coffee  ...         0.0
# ...                ...                                  ...  ...         ...
# 2572                en  Edmund Kemper Part 3: La mort sévit  ...         0.0
# 2573                en                 Guns Along The Bravo  ...         0.0
# 2574                en                            New Breed  ...         0.0
# 2575                cn                                 致命密函  ...         0.0
# 2576                ja                           実録外伝 ゾンビ極道  ...         0.0
#
#       runtime                                   spoken_languages    status  \
# 0        86.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1       100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2       152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3        99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4        99.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 2572     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2573     85.0                                                 []  Released
# 2574     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2575     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 2576     88.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 0         Try to remember the first time magic happened
# 1          The ultimate showdown on a forbidden planet.
# 2                                                   NaN
# 3     Feel the heat, keep the feeling burning, let t...
# 4     There's a fine line between friendship and bet...
# ...                                                 ...
# 2572                                                NaN
# 2573  Evil came to the Southwest until three blazing...
# 2574                                                NaN
# 2575                                                NaN
# 2576                                                NaN
#
#                                     title  video  vote_average vote_count  \
# 0                         The Fantasticks    0.0         5.500       22.0
# 1                           For the Cause    0.0         5.100        8.0
# 2                                    Gang    0.0         4.000        1.0
# 3                    In the Mood for Love    0.0         8.112     2239.0
# 4                          Chinese Coffee    0.0         6.800       50.0
# ...                                   ...    ...           ...        ...
# 2572  Edmund Kemper Part 3: La mort sévit    0.0         0.000        0.0
# 2573                 Guns Along The Bravo    0.0         0.000        0.0
# 2574                            New Breed    0.0         0.000        0.0
# 2575                       Chinese Heroes    0.0         3.000        2.0
# 2576                        Yakuza Zombie    0.0         0.000        0.0
#
#      certification
# 0              NaN
# 1              NaN
# 2              NaN
# 3               PG
# 4                R
# ...            ...
# 2572           NaN
# 2573           NaN
# 2574            NR
# 2575           NaN
# 2576           NaN
#
# [2577 rows x 26 columns]

# %%
# final_2000 = movies['final_tmdb_data_2000.csv']
# final_2001 = movies['final_tmdb_data_2001.csv']

# %%
# final_2000.info()

# %% [markdown]
# ## Basics Extraction

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81762 entries, 0 to 81761
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      81762 non-null  int64
#  1   tconst          81762 non-null  object
#  2   titleType       81762 non-null  object
#  3   primaryTitle    81762 non-null  object
#  4   originalTitle   81762 non-null  object
#  5   isAdult         81762 non-null  int64
#  6   startYear       81762 non-null  float64
#  7   endYear         0 non-null      float64
#  8   runtimeMinutes  81762 non-null  int64
#  9   genres          81762 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.2+ MB

# %%
title_basics = basics[['tconst', 'primaryTitle', 'startYear', 'runtimeMinutes', 'genres']]

# %% [markdown]
# ## Ratings Extraction

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501008 entries, 0 to 501007
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     501008 non-null  int64
#  1   tconst         501008 non-null  object
#  2   averageRating  501008 non-null  float64
#  3   numVotes       501008 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.3+ MB

# %%
title_ratings = ratings[ratings.columns[ratings.columns != 'Unnamed: 0']]

# %%
title_ratings
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000001            5.7      1979
# 1       tt0000002            5.8       265
# 2       tt0000005            6.2      2621
# 3       tt0000006            5.1       182
# 4       tt0000007            5.4       821
# ...           ...            ...       ...
# 501003  tt9916200            8.1       229
# 501004  tt9916204            8.2       263
# 501005  tt9916348            8.3        18
# 501006  tt9916362            6.4      5374
# 501007  tt9916428            3.8        14
#
# [501008 rows x 3 columns]

# %% [markdown]
# ## TMDB Results Extraction

# %%
tmdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2577 non-null   object
#  1   adult                  2577 non-null   float64
#  2   backdrop_path          1410 non-null   object
#  3   belongs_to_collection  208 non-null    object
#  4   budget                 2577 non-null   float64
#  5   genres                 2577 non-null   object
#  6   homepage               171 non-null    object
#  7   id                     2577 non-null   float64
#  8   original_language      2577 non-null   object
#  9   original_title         2577 non-null   object
#  10  overview               2529 non-null   object
#  11  popularity             2577 non-null   float64
#  12  poster_path            2322 non-null   object
#  13  production_companies   2577 non-null   object
#  14  production_countries   2577 non-null   object
#  15  release_date           2553 non-null   object
#  16  revenue                2577 non-null   float64
#  17  runtime                2577 non-null   float64
#  18  spoken_languages       2577 non-null   object
#  19  status                 2577 non-null   object
#  20  tagline                1109 non-null   object
#  21  title                  2577 non-null   object
#  22  video                  2577 non-null   float64
#  23  vote_average           2577 non-null   float64
#  24  vote_count             2577 non-null   float64
#  25  certification          815 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 523.6+ KB

# %% [markdown]
# ## Basics Normalization

# %%
title_basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0043139                        Life of a Beijing Policeman
# 2      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 3      tt0069049                         The Other Side of the Wind
# 4      tt0088751                                  The Naked Monster
# ...          ...                                                ...
# 81757  tt9914942                             Life Without Sara Amat
# 81758  tt9915872                               The Last White Witch
# 81759  tt9916170                                      The Rehearsal
# 81760  tt9916190                                          Safeguard
# 81761  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2013.0             120              Drama,History
# 2         2020.0              70                      Drama
# 3         2018.0             122                      Drama
# 4         2005.0             100       Comedy,Horror,Sci-Fi
# ...          ...             ...                        ...
# 81757     2019.0              74                      Drama
# 81758     2019.0              97       Comedy,Drama,Fantasy
# 81759     2019.0              51                      Drama
# 81760     2020.0              95  Action,Adventure,Thriller
# 81761     2020.0              92              Drama,History
#
# [81762 rows x 5 columns]

# %%
# # Step 1: Getting a list of all individual genres
# genres_list = title_basics['genres'].str.split(',').explode().unique()

# # Step 2: Create a new title_genres table with movie ids duplicated for each genre
# title_genres = title_basics['genres'].str.split(',').explode().reset_index().rename(columns={'genres': 'genre_name'})

# # Step 3: Create a mapper dictionary with numeric ids for each genre
# mapper = {genre: genre_id for genre_id, genre in enumerate(genres_list, start=1)}

# # Step 4: Use the mapper dictionary to replace string genres with numeric genre_ids
# title_genres['genre_id'] = title_genres['genre_name'].map(mapper)

# # Step 5: Convert the mapper dictionary into the final genres table
# genres = pd.DataFrame({'genre_id': list(mapper.values()), 'genre_name': list(mapper.keys())})

# %%
title_genres
# Out:
#         tconst  genre_id
# 0            0         1
# 1            0         2
# 2            0         3
# 3            1         4
# 4            1         5
# ...        ...       ...
# 153201   81760        11
# 153202   81760        12
# 153203   81760        14
# 153204   81761         4
# 153205   81761         5
#
# [153206 rows x 2 columns]

# %%
genres
# Out:
#     genre_id  genre_name
# 0          1      Comedy
# 1          2     Fantasy
# 2          3     Romance
# 3          4       Drama
# 4          5     History
# 5          6      Horror
# 6          7      Sci-Fi
# 7          8   Biography
# 8          9     Mystery
# 9         10     Musical
# 10        11      Action
# 11        12   Adventure
# 12        13       Crime
# 13        14    Thriller
# 14        15       Music
# 15        16   Animation
# 16        17      Family
# 17        18         War
# 18        19       Sport
# 19        20     Western
# 20        21       Adult
# 21        22  Reality-TV
# 22        23        News
# 23        24   Talk-Show
# 24        25   Game-Show

# %% [markdown]
# # Creating MySQL tables

# %%
title_basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0043139                        Life of a Beijing Policeman
# 2      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 3      tt0069049                         The Other Side of the Wind
# 4      tt0088751                                  The Naked Monster
# ...          ...                                                ...
# 81757  tt9914942                             Life Without Sara Amat
# 81758  tt9915872                               The Last White Witch
# 81759  tt9916170                                      The Rehearsal
# 81760  tt9916190                                          Safeguard
# 81761  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2013.0             120              Drama,History
# 2         2020.0              70                      Drama
# 3         2018.0             122                      Drama
# 4         2005.0             100       Comedy,Horror,Sci-Fi
# ...          ...             ...                        ...
# 81757     2019.0              74                      Drama
# 81758     2019.0              97       Comedy,Drama,Fantasy
# 81759     2019.0              51                      Drama
# 81760     2020.0              95  Action,Adventure,Thriller
# 81761     2020.0              92              Drama,History
#
# [81762 rows x 5 columns]

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = title_basics['tconst'].fillna('').map(len).max()
title_len = title_basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
df_schema
# Out:
# {'tconst': String(length=11),
#  'primaryTitle': Text(length=243),
#  'startYear': Float(),
#  'endYear': Float(),
#  'runtimeMinutes': Integer()}

# %%
title_basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0043139                        Life of a Beijing Policeman
# 2      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 3      tt0069049                         The Other Side of the Wind
# 4      tt0088751                                  The Naked Monster
# ...          ...                                                ...
# 81757  tt9914942                             Life Without Sara Amat
# 81758  tt9915872                               The Last White Witch
# 81759  tt9916170                                      The Rehearsal
# 81760  tt9916190                                          Safeguard
# 81761  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2013.0             120              Drama,History
# 2         2020.0              70                      Drama
# 3         2018.0             122                      Drama
# 4         2005.0             100       Comedy,Horror,Sci-Fi
# ...          ...             ...                        ...
# 81757     2019.0              74                      Drama
# 81758     2019.0              97       Comedy,Drama,Fantasy
# 81759     2019.0              51                      Drama
# 81760     2020.0              95  Action,Adventure,Thriller
# 81761     2020.0              92              Drama,History
#
# [81762 rows x 5 columns]

# %%
title_basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)

q = """SELECT * FROM title_basics LIMIT 5"""

pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0043139                        Life of a Beijing Policeman     2013.0
# 2  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 3  tt0069049                         The Other Side of the Wind     2018.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1             120           Drama,History
# 2              70                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %%
title_genres.to_sql('title_genres',engine,dtype=df_schema,if_exists='replace',index=False)

q = """SELECT * FROM title_genres LIMIT 5"""

pd.read_sql(q, engine)
# Out:
#   tconst  genre_id
# 0      0         1
# 1      0         2
# 2      0         3
# 3      1         4
# 4      1         5

# %%
title_ratings.to_sql('title_ratings',engine,dtype=df_schema,if_exists='replace',index=False)

q = """SELECT * FROM title_ratings LIMIT 5"""

pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1979
# 1  tt0000002            5.8       265
# 2  tt0000005            6.2      2621
# 3  tt0000006            5.1       182
# 4  tt0000007            5.4       821

# %%
genres.to_sql('genres',engine,dtype=df_schema,if_exists='replace',index=False)

q = """SELECT * FROM genres LIMIT 5"""

pd.read_sql(q, engine)
# Out:
#    genre_id genre_name
# 0         1     Comedy
# 1         2    Fantasy
# 2         3    Romance
# 3         4      Drama
# 4         5    History

# %%
tmdb_data.to_sql('tmdb_data',engine,dtype=df_schema,if_exists='replace',index=False)

q = """SELECT * FROM tmdb_data LIMIT 5"""

pd.read_sql(q, engine)
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1  tt0113092    0.0                              None
# 2  tt0116391    0.0                              None
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
#
#                                belongs_to_collection      budget  \
# 0                                               None  10000000.0
# 1                                               None         0.0
# 2                                               None         0.0
# 3  {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
# 4                                               None         0.0
#
#                                               genres homepage        id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...     None   62127.0
# 1           [{'id': 878, 'name': 'Science Fiction'}]     None  110977.0
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...     None  442869.0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...     None     843.0
# 4                      [{'id': 18, 'name': 'Drama'}]     None   49511.0
#
#   original_language   original_title  ...     revenue  runtime  \
# 0                en  The Fantasticks  ...         0.0     86.0
# 1                en    For the Cause  ...         0.0    100.0
# 2                hi             Gang  ...         0.0    152.0
# 3                cn             花樣年華  ...  14204632.0     99.0
# 4                en   Chinese Coffee  ...         0.0     99.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                               None                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average vote_count certification
# 0    0.0         5.500       22.0          None
# 1    0.0         5.100        8.0          None
# 2    0.0         4.000        1.0          None
# 3    0.0         8.112     2239.0            PG
# 4    0.0         6.800       50.0             R
#
# [5 rows x 26 columns]

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
q = """SHOW TABLES"""

pd.read_sql(q, engine)
# Out:
#   Tables_in_movie_db
# 0             genres
# 1       title_basics
# 2       title_genres
# 3      title_ratings
# 4          tmdb_data
